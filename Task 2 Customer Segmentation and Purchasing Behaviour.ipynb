# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
data = pd.read_csv("QVI_data.csv")

# %%
data
# Out:
#         LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0                 1000  2018-10-17          1       1         5
# 1                 1002  2018-09-16          1       2        58
# 2                 1003  2019-03-07          1       3        52
# 3                 1003  2019-03-08          1       4       106
# 4                 1004  2018-11-02          1       5        96
# ...                ...         ...        ...     ...       ...
# 264829         2370701  2018-12-08         88  240378        24
# 264830         2370751  2018-10-01         88  240394        60
# 264831         2370961  2018-10-24         88  240480        70
# 264832         2370961  2018-10-27         88  240481        65
# 264833         2373711  2018-12-14         88  241815        16
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES  \
# 0         Natural Chip        Compny SeaSalt175g         2        6.0
# ...

# %%
#Check for missing values and basic info

# %%
data.head()
# Out:
#    LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0            1000  2018-10-17          1       1         5
# 1            1002  2018-09-16          1       2        58
# 2            1003  2019-03-07          1       3        52
# 3            1003  2019-03-08          1       4       106
# 4            1004  2018-11-02          1       5        96
#
#                                 PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 0  Natural Chip        Compny SeaSalt175g         2        6.0        175
# 1   Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7        150
# 2   Grain Waves Sour    Cream&Chives 210G         1        3.6        210
# 3  Natural ChipCo      Hony Soy Chckn175g         1        3.0        175
# 4          WW Original Stacked Chips 160g         1        1.9        160
#
#         BRAND              LIFESTAGE PREMIUM_CUSTOMER
# 0     NATURAL  YOUNG SINGLES/COUPLES          Premium
# 1         RRD  YOUNG SINGLES/COUPLES       Mainstream
# ...

# %%
# Check for missing values
data.isnull().sum()
# Out:
# LYLTY_CARD_NBR      0
# DATE                0
# STORE_NBR           0
# TXN_ID              0
# PROD_NBR            0
# PROD_NAME           0
# PROD_QTY            0
# TOT_SALES           0
# PACK_SIZE           0
# BRAND               0
# LIFESTAGE           0
# PREMIUM_CUSTOMER    0
# dtype: int64

# %%
# Get basic info about data types and non-null counts
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264834 entries, 0 to 264833
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   LYLTY_CARD_NBR    264834 non-null  int64
#  1   DATE              264834 non-null  object
#  2   STORE_NBR         264834 non-null  int64
#  3   TXN_ID            264834 non-null  int64
#  4   PROD_NBR          264834 non-null  int64
#  5   PROD_NAME         264834 non-null  object
#  6   PROD_QTY          264834 non-null  int64
#  7   TOT_SALES         264834 non-null  float64
#  8   PACK_SIZE         264834 non-null  int64
#  9   BRAND             264834 non-null  object
#  10  LIFESTAGE         264834 non-null  object
#  11  PREMIUM_CUSTOMER  264834 non-null  object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 24.2+ MB

# %%
data['DATE'] = pd.to_datetime(data['DATE'])

# %%
data.head()
# Out:
#    LYLTY_CARD_NBR       DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0            1000 2018-10-17          1       1         5
# 1            1002 2018-09-16          1       2        58
# 2            1003 2019-03-07          1       3        52
# 3            1003 2019-03-08          1       4       106
# 4            1004 2018-11-02          1       5        96
#
#                                 PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 0  Natural Chip        Compny SeaSalt175g         2        6.0        175
# 1   Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7        150
# 2   Grain Waves Sour    Cream&Chives 210G         1        3.6        210
# 3  Natural ChipCo      Hony Soy Chckn175g         1        3.0        175
# 4          WW Original Stacked Chips 160g         1        1.9        160
#
#         BRAND              LIFESTAGE PREMIUM_CUSTOMER
# 0     NATURAL  YOUNG SINGLES/COUPLES          Premium
# 1         RRD  YOUNG SINGLES/COUPLES       Mainstream
# ...

# %%
# Creating a 'month' column
data['month'] = data['DATE'].dt.to_period('M')
data.head()
# Out:
#    LYLTY_CARD_NBR       DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0            1000 2018-10-17          1       1         5
# 1            1002 2018-09-16          1       2        58
# 2            1003 2019-03-07          1       3        52
# 3            1003 2019-03-08          1       4       106
# 4            1004 2018-11-02          1       5        96
#
#                                 PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 0  Natural Chip        Compny SeaSalt175g         2        6.0        175
# 1   Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7        150
# 2   Grain Waves Sour    Cream&Chives 210G         1        3.6        210
# 3  Natural ChipCo      Hony Soy Chckn175g         1        3.0        175
# 4          WW Original Stacked Chips 160g         1        1.9        160
#
#         BRAND              LIFESTAGE PREMIUM_CUSTOMER    month
# 0     NATURAL  YOUNG SINGLES/COUPLES          Premium  2018-10
# ...

# %%
# Analyzing the  total sales per month:

# %%
# Group by month and calculate total sales
monthly_sales = data.groupby('month')['TOT_SALES'].sum().reset_index()

# %%
monthly_sales
# Out:
#       month  TOT_SALES
# 0   2018-07  165275.30
# 1   2018-08  158081.05
# 2   2018-09  160522.00
# 3   2018-10  164415.70
# 4   2018-11  160233.70
# 5   2018-12  167913.40
# 6   2019-01  162642.30
# 7   2019-02  150665.00
# 8   2019-03  166265.20
# 9   2019-04  159845.10
# 10  2019-05  156717.65
# 11  2019-06  160538.60

# %%
# identifying top product by total sale:

# %%
top_products = data.groupby('PROD_NAME')['TOT_SALES'].sum().sort_values(ascending=False).head(5)
top_products
# Out:
# PROD_NAME
# Dorito Corn Chp     Supreme 380g            39052.0
# Smiths Crnkle Chip  Orgnl Big Bag 380g      36367.6
# Smiths Crinkle Chips Salt & Vinegar 330g    34804.2
# Kettle Mozzarella   Basil & Pesto 175g      34457.4
# Smiths Crinkle      Original 330g           34302.6
# Name: TOT_SALES, dtype: float64

# %%
 # Identifying top 5 brands by quantity sold

# %%
top_brands = data.groupby('BRAND')['PROD_QTY'].sum().sort_values(ascending=False).head(5)
top_brands
# Out:
# BRAND
# KETTLE      79051
# SMITHS      60339
# DORITOS     53816
# PRINGLES    48019
# RRD         33646
# Name: PROD_QTY, dtype: int64

# %%
# Group by LIFESTAGE and PREMIUM_CUSTOMER, and calculate total sales
customer_segments = data.groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER'])['TOT_SALES'].sum().reset_index()

# %%
customer_segments
# Out:
#                  LIFESTAGE PREMIUM_CUSTOMER  TOT_SALES
# 0   MIDAGE SINGLES/COUPLES           Budget   35514.80
# 1   MIDAGE SINGLES/COUPLES       Mainstream   90803.85
# 2   MIDAGE SINGLES/COUPLES          Premium   58432.65
# 3             NEW FAMILIES           Budget   21928.45
# 4             NEW FAMILIES       Mainstream   17013.90
# 5             NEW FAMILIES          Premium   11491.10
# 6           OLDER FAMILIES           Budget  168363.25
# 7           OLDER FAMILIES       Mainstream  103445.55
# 8           OLDER FAMILIES          Premium   80658.40
# 9    OLDER SINGLES/COUPLES           Budget  136769.80
# 10   OLDER SINGLES/COUPLES       Mainstream  133393.80
# 11   OLDER SINGLES/COUPLES          Premium  132263.15
# 12                RETIREES           Budget  113147.80
# 13                RETIREES       Mainstream  155677.05
# 14                RETIREES          Premium   97646.05
# 15          YOUNG FAMILIES           Budget  139345.85
# ...

# %%
# Segment customers based on LIFESTAGE and PREMIUM_CUSTOMER :

# %%
# Sort to see who spends the most
customer_segments = customer_segments.sort_values(by='TOT_SALES', ascending=False)

# %%
customer_segments
# Out:
#                  LIFESTAGE PREMIUM_CUSTOMER  TOT_SALES
# 6           OLDER FAMILIES           Budget  168363.25
# 19   YOUNG SINGLES/COUPLES       Mainstream  157621.60
# 13                RETIREES       Mainstream  155677.05
# 15          YOUNG FAMILIES           Budget  139345.85
# 9    OLDER SINGLES/COUPLES           Budget  136769.80
# 10   OLDER SINGLES/COUPLES       Mainstream  133393.80
# 11   OLDER SINGLES/COUPLES          Premium  132263.15
# 12                RETIREES           Budget  113147.80
# 7           OLDER FAMILIES       Mainstream  103445.55
# 14                RETIREES          Premium   97646.05
# 16          YOUNG FAMILIES       Mainstream   92788.75
# 1   MIDAGE SINGLES/COUPLES       Mainstream   90803.85
# 17          YOUNG FAMILIES          Premium   84025.50
# 8           OLDER FAMILIES          Premium   80658.40
# 18   YOUNG SINGLES/COUPLES           Budget   61141.60
# 2   MIDAGE SINGLES/COUPLES          Premium   58432.65
# ...

# %%
#Compare average product quantity purchased per transaction by segment

# %%
avg_qty = data.groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER'])['PROD_QTY'].mean().reset_index()
avg_qty = avg_qty.sort_values(by='PROD_QTY', ascending=False)
avg_qty
# Out:
#                  LIFESTAGE PREMIUM_CUSTOMER  PROD_QTY
# 7           OLDER FAMILIES       Mainstream  1.948610
# 6           OLDER FAMILIES           Budget  1.945812
# 8           OLDER FAMILIES          Premium  1.945576
# 15          YOUNG FAMILIES           Budget  1.940749
# 16          YOUNG FAMILIES       Mainstream  1.940342
# 17          YOUNG FAMILIES          Premium  1.937732
# 11   OLDER SINGLES/COUPLES          Premium  1.914273
# 9    OLDER SINGLES/COUPLES           Budget  1.913403
# 1   MIDAGE SINGLES/COUPLES       Mainstream  1.911656
# 10   OLDER SINGLES/COUPLES       Mainstream  1.910525
# 14                RETIREES          Premium  1.900122
# 12                RETIREES           Budget  1.892244
# 0   MIDAGE SINGLES/COUPLES           Budget  1.891633
# 2   MIDAGE SINGLES/COUPLES          Premium  1.889727
# 13                RETIREES       Mainstream  1.887543
# 5             NEW FAMILIES          Premium  1.860919
# ...

# %%
# Compare average total sales per transaction by segment :

# %%
avg_sales = data.groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER'])['TOT_SALES'].mean().reset_index()
avg_sales = avg_sales.sort_values(by='TOT_SALES', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 avg_sales = data.groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER'])['TOT_SALES'].mean().reset_index()
#       2 avg_sales = avg_sales.sort_values(by='TOT_SALES', ascending=False)
#
# NameError: name 'data' is not defined

# %%
avg_sales
# Out:
#                  LIFESTAGE PREMIUM_CUSTOMER  TOT_SALES
# 1   MIDAGE SINGLES/COUPLES       Mainstream   7.647284
# 19   YOUNG SINGLES/COUPLES       Mainstream   7.558339
# 14                RETIREES          Premium   7.456174
# 11   OLDER SINGLES/COUPLES          Premium   7.449766
# 12                RETIREES           Budget   7.443445
# 9    OLDER SINGLES/COUPLES           Budget   7.430315
# 4             NEW FAMILIES       Mainstream   7.317806
# 3             NEW FAMILIES           Budget   7.297321
# 15          YOUNG FAMILIES           Budget   7.287201
# 10   OLDER SINGLES/COUPLES       Mainstream   7.282116
# 6           OLDER FAMILIES           Budget   7.269570
# 17          YOUNG FAMILIES          Premium   7.266756
# 7           OLDER FAMILIES       Mainstream   7.262395
# 13                RETIREES       Mainstream   7.252262
# 5             NEW FAMILIES          Premium   7.231655
# 8           OLDER FAMILIES          Premium   7.208079
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('QVI_data.csv')

# Show first few rows
df.head()
# Out:
#    LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0            1000  2018-10-17          1       1         5
# 1            1002  2018-09-16          1       2        58
# 2            1003  2019-03-07          1       3        52
# 3            1003  2019-03-08          1       4       106
# 4            1004  2018-11-02          1       5        96
#
#                                 PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 0  Natural Chip        Compny SeaSalt175g         2        6.0        175
# 1   Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7        150
# 2   Grain Waves Sour    Cream&Chives 210G         1        3.6        210
# 3  Natural ChipCo      Hony Soy Chckn175g         1        3.0        175
# 4          WW Original Stacked Chips 160g         1        1.9        160
#
#         BRAND              LIFESTAGE PREMIUM_CUSTOMER
# 0     NATURAL  YOUNG SINGLES/COUPLES          Premium
# 1         RRD  YOUNG SINGLES/COUPLES       Mainstream
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group by LIFESTAGE and PREMIUM_CUSTOMER to get total spend
total_spend = data.groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER'])['TOT_SALES'].sum().reset_index()

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(data=total_spend, x='TOT_SALES', y='LIFESTAGE', hue='PREMIUM_CUSTOMER')
plt.title('Total Spend by Customer Segment and Premium Category')
plt.xlabel('Total Spend')
plt.ylabel('Customer Segment (Lifestage)')
plt.tight_layout()
plt.show()

# %%
# Average Spend per Transaction by Lifestage and Premium Category

# %%
# Group and calculate average spend per transaction
avg_spend = data.groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER'])['TOT_SALES'].mean().reset_index()

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(data=avg_spend, x='TOT_SALES', y='LIFESTAGE', hue='PREMIUM_CUSTOMER')
plt.title('Average Spend per Transaction')
plt.xlabel('Average Spend')
plt.ylabel('Customer Segment (Lifestage)')
plt.tight_layout()
plt.show()

# %%
# Total Quantity of Products Purchased by Customer Segment

# %%
# Group and calculate total quantity purchased
total_qty = data.groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER'])['PROD_QTY'].sum().reset_index()

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(data=total_qty, x='PROD_QTY', y='LIFESTAGE', hue='PREMIUM_CUSTOMER')
plt.title('Total Product Quantity by Segment')
plt.xlabel('Total Quantity')
plt.ylabel('Customer Segment (Lifestage)')
plt.tight_layout()
plt.show()

# %%
#Pie Chart – Total Spend Distribution by Lifestage

# %%
# Total spend by LIFESTAGE
spend_pie = data.groupby('LIFESTAGE')['TOT_SALES'].sum()

# Plot
plt.figure(figsize=(8, 8))
plt.pie(spend_pie, labels=spend_pie.index, autopct='%1.1f%%', startangle=140)
plt.title('Total Spend Distribution by Lifestage')
plt.axis('equal')
plt.show()

# %%
#Top 10 Brands by Total Sales

# %%
# Group by brand and get total sales
top_brands = data.groupby('BRAND')['TOT_SALES'].sum().sort_values(ascending=False).head(10).reset_index()

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(data=top_brands, x='TOT_SALES', y='BRAND', palette='viridis')
plt.title('Top 10 Brands by Total Sales')
plt.xlabel('Total Sales')
plt.ylabel('Brand')
plt.tight_layout()
plt.show()

# %%
#Monthly Sales Trend

# %%
monthly_sales.dtypes
# Out:
# month        period[M]
# TOT_SALES      float64
# dtype: object

# %%
print(monthly_sales['TOT_SALES'].head())
print(monthly_sales['TOT_SALES'].dtype)
# Out:
# 0    165275.30
# 1    158081.05
# 2    160522.00
# 3    164415.70
# 4    160233.70
# Name: TOT_SALES, dtype: float64
# float64

# %%
monthly_sales['month'] = monthly_sales['month'].astype(str)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert 'month' to string
monthly_sales['month'] = monthly_sales['month'].astype(str)

# Plot
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_sales, x='month', y='TOT_SALES', marker='o')
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
transaction = pd.read_csv("QVI_data.csv")

# Create a BRAND_NAME column by extracting first word from PROD_NAME
transaction["BRAND_NAME"] = transaction["PROD_NAME"].str.split().str[0]

# Group by brand and sum the total sales
brand_sales = transaction.groupby("BRAND_NAME")["TOT_SALES"].sum().sort_values(ascending=False)

# Plot the top 10 brands by total sales
plt.figure(figsize=(10, 6))
brand_sales.head(10).plot(kind='bar', color='skyblue')
plt.title('Top 10 Brands by Total Sales')
plt.xlabel('Brand')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
